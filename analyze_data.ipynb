# %%
import os
import utils.data as du
import torch
import numpy as np
from matplotlib import pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In [19], line 5
#       3 import torch
#       4 import numpy as np
# ----> 5 from matplotlib.pyplot import plt
#
# ImportError: cannot import name 'plt' from 'matplotlib.pyplot' (/home/phoebus/MPRINCE/anaconda3/envs/soc_xrd/lib/python3.9/site-packages/matplotlib/pyplot.py)

# %%
dataset_path = '../../Data/robo_steer/raw'

# %%
user_counts = {}
for user_path in os.listdir(dataset_path):
    user_counts[user_path] = len(list(os.listdir(os.path.join(dataset_path, user_path, 'Scans'))))

# %%
for user in user_counts.keys():
    print(f'{user} {user_counts[user]}')
# Out:
# BioSAXS 18
# Chaney 33
# CLi 11
# Driscoll 61
# fZhang 62
# gJohnson 32
# Kuzmenko_Oct11 31
# Kuzmenko_Oct12 48
# Leal2 66
# Macfarlane 202
# Mahanthappa 40
# Mengel 2
# Mengel2 6
# Schaefer 35
# Srivastava 67
# Thomas 15
# tLiSep25 60
# WangOct14 2
# Wang_Wenjie 156
# yHu1 4
# yRen 8
# zuoSep21 1

# %%
scan_list = du.get_all_data_fp('../../Data/robo_steer/raw')

# %%
pos_starts = []
pos_ranges = []
read_starts = []
read_ranges = []
num_readings = []
for scan_fp in scan_list:
    scan = du.read_pos_dat(scan_fp)
    if len(scan.pos) > 1:
        pos_starts.append(scan.pos[0])
        pos_ranges.append(np.max(scan.pos) - np.min(scan.pos))
        read_starts.append(scan.reads[0])
        read_ranges.append(np.max(scan.reads) - np.min(scan.reads))
        num_readings.append(len(scan.pos))

# %%
plt.hist(pos_ranges)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [18], line 2
#       1 np.max(pos_starts)
# ----> 2 plt.hist(pos_ranges)
#
# NameError: name 'plt' is not defined

# %%
num_readings
# Out:
# [31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  21,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  21,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  51,
#  51,
#  51,
#  41,
#  41,
#  41,
#  51,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  51,
#  31,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  31,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  31,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  31,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  41,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  41,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  21,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  21,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  21,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  21,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  31,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  41,
#  51,
#  51,
#  51,
#  51,
#  51,
#  31,
#  31,
#  41,
#  41,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  30,
#  30,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  30,
#  31,
#  30,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  30,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  30,
#  30,
#  31,
#  30,
#  31,
#  31,
#  30,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  26,
#  26,
#  26,
#  31,
#  26,
#  26,
#  26,
#  26,
#  26,
#  25,
#  26,
#  31,
#  31,
#  26,
#  26,
#  26,
#  26,
#  26,
#  26,
#  26,
#  31,
#  26,
#  26,
#  26,
#  25,
#  26,
#  25,
#  26,
#  31,
#  25,
#  26,
#  31,
#  25,
#  31,
#  26,
#  26,
#  26,
#  26,
#  26,
#  26,
#  26,
#  26,
#  25,
#  26,
#  25,
#  26,
#  25,
#  25,
#  31,
#  30,
#  31,
#  31,
#  30,
#  31,
#  30,
#  30,
#  31,
#  31,
#  31,
#  30,
#  31,
#  30,
#  21,
#  31,
#  31,
#  31,
#  41,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  51,
#  51,
#  51,
#  31,
#  31,
#  51,
#  31,
#  51,
#  51,
#  51,
#  51,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  21,
#  31,
#  51,
#  51,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  51,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  31,
#  51,
#  51,
#  51,
#  51,
#  51,
#  40,
#  30,
#  41,
#  41,
#  41,
#  41,
#  21,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  21,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  21,
#  21,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  31,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  21,
#  21,
#  21,
#  21,
#  21,
#  21,
#  21,
#  21,
#  21,
#  41,
#  41,
#  31,
#  31,
#  41,
#  31,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  41,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  50,
#  51,
#  51,
#  51,
#  51,
#  50,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  50,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  50,
#  51,
#  51,
#  51,
#  50,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  50,
#  51,
#  51,
#  51,
#  50,
#  51,
#  51,
#  51,
#  51,
#  21,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  50,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  31,
#  41,
#  41,
#  31,
#  41,
#  31,
#  41,
#  41]

# %%
# Out:
# PosData(usr_pos=31.42164, pos_readings=tensor([[  28.0000, 2807.0000],
#         [  28.2020, 2791.0000],
#         [  28.4000, 2808.0000],
#         [  28.6020, 2797.0000],
#         [  28.8000, 2805.0000],
#         [  28.9980, 2802.0000],
#         [  29.2000, 2841.0000],
#         [  29.3990, 2775.0000],
#         [  29.6010, 2809.0000],
#         [  29.7990, 2796.0000],
#         [  30.0010, 2787.0000],
#         [  30.1990, 2816.0000],
#         [  30.4010, 2813.0000],
#         [  30.6000, 2797.0000],
#         [  30.8020, 2737.0000],
#         [  31.0000, 2028.0000],
#         [  31.1980, 1836.0000],
#         [  31.4000, 1785.0000],
#         [  31.5990, 1789.0000],
#         [  31.8010, 2449.0000],
#         [  31.9990, 2766.0000],
#         [  32.2010, 2791.0000],
#         [  32.3990, 2784.0000],
#         [  32.6010, 2774.0000],
#         [  32.8000, 2786.0000],
#         [  33.0020, 2812.0000],
#         [  33.2000, 2806.0000],
#         [  33.3980, 2766.0000],
#         [  33.6000, 2756.0000],
#         [  33.7980, 2801.0000],
#         [  34.0000, 2814.0000]]))
